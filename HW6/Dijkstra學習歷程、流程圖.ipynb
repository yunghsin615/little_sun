# %% [markdown]
# Dijkstra - Shortest Path 最短路徑
# =
# 最短路徑的運算就是給一個起點(s)，計算他到每個點的最短路徑<br>
# 設兩個list，初始狀態一個全部點都是無限(dist)，另一個都是False(test)，這是為了檢測各點是否已經被走過了<br>
# 迴圈設while test != [True] * self.V，也就是代表還沒有把所有點走完<br>
# 再來助教給的測資的0是自己到自己的路徑，或是點不在隔壁的路徑<br>
# 所以當條件一:g.graph不等於0，和條件二:dist[現在點的index] + g.graph小於原來的dist[0-self.V的index]<br>
# 兩個條件都達成的時候，dist[0-self.V的index]會等於dist[現在點的index] + g.graph，因為路徑更短<br>
# 接下來就是找test=False(還沒被走過)的情況下，dist裡面最小的那個點<br>
# 找出最小的點和那個點的index，再把test[index]變成True<br>
# 最後dist就是從起點開始到各點的最短路徑，把它變成dictionary的形式就完成了!<br>

# %%
#12/25聖誕節 Dijkstra
from collections import defaultdict 

class Graph(): 

    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [] 
        self.graph_matrix = [[0 for column in range(vertices)]  
                    for row in range(vertices)]
    #def addEdge(self,u,v,w): 
        
        
    def Dijkstra(self, s): 
        test = [False] * self.V 
        dist = [float('inf')] * self.V
        
        dist[s] = 0
        for i in range(0,len(g.graph[s])):
            if g.graph[s][i] > 0 :
                dist[i] = g.graph[s][i]
        test[s] = True
        
        m = float('inf')
        for i in range(self.V):
            if test[i] == False and dist[i] < m :
                m = dist[i]
                s = i         
        test[s] = True
        
        while test != [True] * self.V:
            for i in range(self.V):
                if g.graph[s][i] != 0 and dist[s] + g.graph[s][i] < dist[i]:
                    dist[i] = dist[s] + g.graph[s][i]
                           
            m = float('inf')
            for k in range(self.V):
                if test[k] == False and dist[k] < m :
                    m = dist[k]
                    s = k         
            test[s] = True
            
            if test == [True] * self.V:
                for i in range(self.V):
                    print (i,dist[i])

# %%
g = Graph(9)
g.graph=[[0,4,0,0,0,0,0,8,0],
         [4,0,8,0,0,0,0,11,0],
         [0,8,0,7,0,4,0,0,2],
         [0,0,7,0,9,14,0,0,0],
         [0,0,0,9,0,10,0,0,0],
         [0,0,4,14,10,0,2,0,0],
         [0,0,0,0,0,2,0,1,6],
         [8,11,0,0,0,0,1,0,7],
         [0,0,2,0,0,0,6,7,0]
        ];

print("Dijkstra",g.Dijkstra(0)) #output形式不是助教指定的
# Out:
# 0 0
# 1 4
# 2 12
# 3 19
# 4 21
# 5 11
# 6 9
# 7 8
# 8 14
# Dijkstra None

# %%
#12/27 Dijkstra
from collections import defaultdict 

class Graph(): 

    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [] 
        self.graph_matrix = [[0 for column in range(vertices)]  
                    for row in range(vertices)]
    #def addEdge(self,u,v,w): 
        
        
    def Dijkstra(self, s): 
        test = [False] * self.V 
        dist = [float('inf')] * self.V
        
        dist[s] = 0
        for i in range(0,len(g.graph[s])):
            if g.graph[s][i] > 0 :
                dist[i] = g.graph[s][i]
        test[s] = True
        
        m = float('inf')
        for i in range(self.V):
            if test[i] == False and dist[i] < m :
                m = dist[i]
                s = i         
        test[s] = True
        
        while test != [True] * self.V:
            for i in range(self.V):
                if g.graph[s][i] != 0 and dist[s] + g.graph[s][i] < dist[i]:
                    dist[i] = dist[s] + g.graph[s][i]
                           
            m = float('inf')
            for k in range(self.V):
                if test[k] == False and dist[k] < m :
                    m = dist[k]
                    s = k         
            test[s] = True
            
            diction = {} 
            if test == [True] * self.V:
                for i in range(self.V):
                    #這個str是讓index 0能變'0'
                    diction[str(i)] = dist[i]
                return diction

# %%
g = Graph(9)
g.graph=[[0,4,0,0,0,0,0,8,0],
         [4,0,8,0,0,0,0,11,0],
         [0,8,0,7,0,4,0,0,2],
         [0,0,7,0,9,14,0,0,0],
         [0,0,0,9,0,10,0,0,0],
         [0,0,4,14,10,0,2,0,0],
         [0,0,0,0,0,2,0,1,6],
         [8,11,0,0,0,0,1,0,7],
         [0,0,2,0,0,0,6,7,0]
        ];

print("Dijkstra",g.Dijkstra(0))
# Out:
# Dijkstra {'0': 0, '1': 4, '2': 12, '3': 19, '4': 21, '5': 11, '6': 9, '7': 8, '8': 14}

# %% [markdown]
# Kruskal - Minimun Spanning Tree 最小生成樹
# =
# 最小生成樹是把每個點都連在一起，但不能形成loop，也就是不能形成三角形這種圍成一圈的圖形<br>
# 設兩個list，初始狀態一個全部都-1，一個是空的<br>
# 因為每個edge照理來說都要測過，所以迴圈的限制是g.graph的長度<br>
# 再來分成兩個大項<br>
# 一:兩個點的root一樣<br>
# 又分為1.兩個點的root都是-1、2.兩個點的root都不是1<br>
# 二:兩個點的root不一樣<br>
# 又分為1.其中一個點的root是-1、2.兩個點的root不一樣但都不是-1<br>
# 每次迴圈都會把要連結的edge的weight加進test<br>
# **每次連結起來的點都要換成同個root，意思是他們現在連成一條線<br>
# 所以當有兩條不同root的線要連在一起時，其中一條的所有root要全部換成跟另一條一樣的root，代表成為同一條線了**<br>
# diction的key是放起點到終點，value是放test的最後一項，也就是新加入的值<br>
# 最後當有n個點的時候，就應該要有n-1個edge，這時迴圈結束<br>
# 實際應用像是連結城市的通訊網，可以計算最低成本<br>

# %% [markdown]
# 依照以下的測值可以得知<br>
# 用g.graph.sort()是以每個list的第一項的大小排序，由小到大<br>
# 所以我把weight放在第一項<br>

# %%
from collections import defaultdict 

class Graph(): 

    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [] 
        self.graph_matrix = [[0 for column in range(vertices)]  
                    for row in range(vertices)]
    def addEdge(self,u,v,w): 
        self.graph.append([w,u,v]) 
                    
    def Kruskal(self):
        root = []
        test = []

        for i in range(self.V):
            root.append(-1)
        
        print(root)

# %%
g = Graph(4)
g.addEdge(0,1,10)
g.addEdge(0,2,6)
g.addEdge(0,3,5)
g.addEdge(1,3,15)
g.addEdge(2,3,4)

print(g.graph)
g.graph.sort()
print(g.graph)
# Out:
# [[10, 0, 1], [6, 0, 2], [5, 0, 3], [15, 1, 3], [4, 2, 3]]
# [[4, 2, 3], [5, 0, 3], [6, 0, 2], [10, 0, 1], [15, 1, 3]]

# %%
#12/28最原版的Kruskal 
#原本是手寫直接打上來，發現要改的地方很多
from collections import defaultdict 

class Graph(): 

    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [] 
        self.graph_matrix = [[0 for column in range(vertices)]  
                    for row in range(vertices)]
    def addEdge(self,u,v,w): 
        self.graph.append([w,u,v]) #增加的順序是權重、起點、終點
    
    def Kruskal(self):
        g.graph.sort() #sort會依第一項由小到大，所以是以權重排序
        root = []
        test = []

        for i in range(self.V):
            root.append(-1)

        if g.graph[1][2] < g.graph[1][3]:
            root[v] = u
            root[u] = u
        else:
            root[u] = v
            root[v] = v
        test.append(1) #test加1單純知道長度
        test.append(1)
        
        while len(test) < len(root):
            if root[u] != root[v]:
                if root[u] == -1:
                    root[u] = root[v]
                    test.append(1)
                elif root[v] == -1:
                    root[v] = root[u]
                    test.append(1)
                else:
                    pass
                    #缺s、e都!=1 & root不一樣
                    
            elif root[u] == root[v]:
                if root[u] == -1:
                    if u < v:
                        root[v] = u
                        root[u] = u

                    else:
                        root[u] = v
                        root[v] = v
                        
                test.append(1)
                test.append(1)
                    
        return root

# %%
from collections import defaultdict 

class Graph(): 

    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [] 
        self.graph_matrix = [[0 for column in range(vertices)]  
                    for row in range(vertices)]
    def addEdge(self,u,v,w): 
        self.graph.append([w,u,v]) #增加的順序是權重、起點、終點
    
    def Kruskal(self):
        g.graph.sort() #sort會依第一項由小到大，所以是以權重排序
        root = []
        test = []
        diction={} #Dijkstra是最後才加diction，這邊我從一開始就設空的，一步一步加

        for i in range(self.V): #每個點的root
            root.append(-1)

        if g.graph[0][1] < g.graph[0][2]:
            root[g.graph[0][2]] = g.graph[0][1]
            root[g.graph[0][1]] = g.graph[0][1]
        else:
            root[g.graph[0][1]] = g.graph[0][2]
            root[g.graph[0][2]] = g.graph[0][2]
        test.append(g.graph[0][0]) #test改成加入每條edge的weight
        diction[g.graph[0][1],"-",g.graph[0][2]] = test[0]
        
        for i in range(1,self.V):
                
            if root[g.graph[i][1]] != root[g.graph[i][2]]:
                if root[g.graph[i][1]] == -1:
                    root[g.graph[i][1]] = root[g.graph[i][2]]
                    test.append(g.graph[i][0])
                    diction[g.graph[i][1],'-',g.graph[i][2]] = test[-1]
          
                elif root[g.graph[i][2]] == -1:
                    root[g.graph[i][2]] = root[g.graph[i][1]]
                    test.append(g.graph[i][0])
                    diction[g.graph[i][1],'-',g.graph[i][2]]= test[-1] 

                else:
                    pass
                    #缺s、e都!=-1 & root不一樣
                    
            elif root[g.graph[i][1]] == root[g.graph[i][2]]:
                if root[g.graph[i][1]] == -1:
                    if g.graph[i][1] < g.graph[i][2]:
                        root[g.graph[i][2]] = g.graph[i][1]
                        root[g.graph[i][1]] = g.graph[i][1]

                    else:
                        root[g.graph[i][1]] = g.graph[i][2]
                        root[g.graph[i][2]] = g.graph[i][2]
                else:
                    continue

            if len(test) == (len(root)-1):   
                return diction

# %%
#其實程式碼還不完整，但因為測資比較簡易所以答案是對的
g = Graph(4)
g.addEdge(0,1,10)
g.addEdge(0,2,6)
g.addEdge(0,3,5)
g.addEdge(1,3,15)
g.addEdge(2,3,4)

print("Kruskal",g.Kruskal())
# Out:
# Kruskal {(2, '-', 3): 4, (0, '-', 3): 5, (0, '-', 1): 10}

# %%
from collections import defaultdict 

class Graph(): 

    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [] 
        self.graph_matrix = [[0 for column in range(vertices)]  
                    for row in range(vertices)]
        
    def addEdge(self,u,v,w): 
        self.graph.append([w,u,v]) #增加的順序是權重、起點、終點
    
    def Dijkstra(self, s): 
        test = [False] * self.V 
        dist = [float('inf')] * self.V
        
        dist[s] = 0
        for i in range(0,len(g.graph[s])):
            if g.graph[s][i] > 0 :
                dist[i] = g.graph[s][i]
        test[s] = True
        
        m = float('inf')
        for i in range(self.V):
            if test[i] == False and dist[i] < m :
                m = dist[i]
                s = i         
        test[s] = True
        
        while test != [True] * self.V:
            for i in range(self.V):
                if g.graph[s][i] != 0 and dist[s] + g.graph[s][i] < dist[i]:
                    dist[i] = dist[s] + g.graph[s][i]
                           
            m = float('inf')
            for k in range(self.V):
                if test[k] == False and dist[k] < m :
                    m = dist[k]
                    s = k         
            test[s] = True
            
            diction = {} 
            if test == [True] * self.V:
                for i in range(self.V):
                    diction[str(i)] = dist [i]
                return diction
    def Kruskal(self):
        g.graph.sort() #sort會依第一項由小到大，所以是以權重排序
        root = []
        test = []
        diction={} #Dijkstra是最後才加diction，這邊我從一開始就設空的，一步一步加

        for i in range(self.V): #每個點的root
            root.append(-1)
        
        if g.graph[0][1] < g.graph[0][2]:
            root[g.graph[0][2]] = g.graph[0][1]
            root[g.graph[0][1]] = g.graph[0][1]
        else:
            root[g.graph[0][1]] = g.graph[0][2]
            root[g.graph[0][2]] = g.graph[0][2]
        test.append(g.graph[0][0]) #test改成加入每條edge的weight
        diction[g.graph[0][1],g.graph[0][2]] = test[0]
        
        for i in range(1,len(g.graph)):
                
            if root[g.graph[i][1]] != root[g.graph[i][2]]: #兩個root不一樣
                if root[g.graph[i][1]] == -1: #起點是-1
                    root[g.graph[i][1]] = root[g.graph[i][2]]
                    test.append(g.graph[i][0])
                    diction[g.graph[i][1],g.graph[i][2]] = test[-1]
          
                elif root[g.graph[i][2]] == -1: #終點是-1
                    root[g.graph[i][2]] = root[g.graph[i][1]]
                    test.append(g.graph[i][0])
                    diction[g.graph[i][1],g.graph[i][2]]= test[-1] 

                else:  #都不是-1，代表他們都有自己的線，現在要連接在一起
                    if root[g.graph[i][1]] > root[g.graph[i][2]]:
                        for k in range(self.V):
                            h = root[g.graph[i][1]]
                            if root[k] == h:
                                root[k] = root[g.graph[i][2]]
                        test.append(g.graph[i][0])
                        diction[g.graph[i][1],g.graph[i][2]]= test[-1]
                            
                    else:
                        for k in range(self.V):
                            h = root[g.graph[i][2]]
                            if root[k] == h:
                                root[k] = root[g.graph[i][1]]
                        test.append(g.graph[i][0])
                        diction[g.graph[i][1],g.graph[i][2]]= test[-1]

                    
            elif root[g.graph[i][1]] == root[g.graph[i][2]]: #兩個root一樣
                if root[g.graph[i][1]] == -1: #都是-1
                    if g.graph[i][1] < g.graph[i][2]:
                        root[g.graph[i][2]] = g.graph[i][1]
                        root[g.graph[i][1]] = g.graph[i][1]
                        test.append(g.graph[i][0])
                        diction[g.graph[i][1],g.graph[i][2]]= test[-1]

                    else: 
                        root[g.graph[i][1]] = g.graph[i][2]
                        root[g.graph[i][2]] = g.graph[i][2]
                        test.append(g.graph[i][0])
                        diction[g.graph[i][1],g.graph[i][2]]= test[-1]
                else: #都不是-1，所以不用連edge
                    continue
                    

            if len(test) == (len(root)-1):   
                return diction

# %%
g = Graph(7)
g.addEdge(0, 1, 5)
g.addEdge(0, 5, 3)
g.addEdge(1, 0, 5)
g.addEdge(1, 2, 10)
g.addEdge(1, 4, 1)
g.addEdge(1, 6, 4)
g.addEdge(2, 1, 10)
g.addEdge(2, 3, 5)
g.addEdge(2, 6, 8)
g.addEdge(3, 2, 5)
g.addEdge(3, 4, 7)
g.addEdge(3, 6, 9)
g.addEdge(4, 1, 1)
g.addEdge(4, 3, 7)
g.addEdge(4, 5, 6)
g.addEdge(4, 6, 2)
g.addEdge(5, 0, 3)
g.addEdge(5, 4, 6)
g.addEdge(6, 1, 4)
g.addEdge(6, 2, 8)
g.addEdge(6, 3, 9)
g.addEdge(6, 4, 2)

print("Kruskal",g.Kruskal()) #(1,4,1)(4,6,2)(0,5,3)(0,1,5)(2,3,5)(3,4,7) #最後一個edge錯了
# Out:
# Kruskal {(1, 4): 1, (4, 6): 2, (0, 5): 3, (0, 1): 5, (2, 3): 5, (4, 5): 6}

# %%
from collections import defaultdict 

class Graph(): 

    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [] 
        self.graph_matrix = [[0 for column in range(vertices)]  
                    for row in range(vertices)]
        
    def addEdge(self,u,v,w): 
        self.graph.append([w,u,v]) #增加的順序是權重、起點、終點
    
    def Dijkstra(self, s): 
        test = [False] * self.V 
        dist = [float('inf')] * self.V
        
        dist[s] = 0
        for i in range(0,len(g.graph[s])):
            if g.graph[s][i] > 0 :
                dist[i] = g.graph[s][i]
        test[s] = True
        
        m = float('inf')
        for i in range(self.V):
            if test[i] == False and dist[i] < m :
                m = dist[i]
                s = i         
        test[s] = True
        
        while test != [True] * self.V:
            for i in range(self.V):
                if g.graph[s][i] != 0 and dist[s] + g.graph[s][i] < dist[i]:
                    dist[i] = dist[s] + g.graph[s][i]
                           
            m = float('inf')
            for k in range(self.V):
                if test[k] == False and dist[k] < m :
                    m = dist[k]
                    s = k         
            test[s] = True
            
            diction = {} 
            if test == [True] * self.V:
                for i in range(self.V):
                    diction[str(i)] = dist [i]
                return diction
    def Kruskal(self):
        g.graph.sort() #sort會依第一項由小到大，所以是以權重排序
        root = []
        test = []
        diction={} #Dijkstra是最後才加diction，這邊我從一開始就設空的，一步一步加

        for i in range(self.V): #每個點的root
            root.append(-1)
        
        if g.graph[0][1] < g.graph[0][2]:
            root[g.graph[0][2]] = g.graph[0][1]
            root[g.graph[0][1]] = g.graph[0][1]
        else:
            root[g.graph[0][1]] = g.graph[0][2]
            root[g.graph[0][2]] = g.graph[0][2]
        test.append(g.graph[0][0]) #test改成加入每條edge的weight
        diction[g.graph[0][1],g.graph[0][2]] = test[0]
        
        for i in range(1,len(g.graph)):
                
            if root[g.graph[i][1]] != root[g.graph[i][2]]: #兩個root不一樣
                if root[g.graph[i][1]] == -1: #起點是-1
                    root[g.graph[i][1]] = root[g.graph[i][2]]
                    test.append(g.graph[i][0])
                    diction[g.graph[i][1],g.graph[i][2]] = test[-1]
          
                elif root[g.graph[i][2]] == -1: #終點是-1
                    root[g.graph[i][2]] = root[g.graph[i][1]]
                    test.append(g.graph[i][0])
                    diction[g.graph[i][1],g.graph[i][2]]= test[-1] 

                else:  #都不是-1，代表他們都有自己的線，現在要連接在一起
                    if root[g.graph[i][1]] > root[g.graph[i][2]]:
                        h = root[g.graph[i][1]] #!!!原本的h放在迴圈裡，這樣他會因為i的不同而更動h的值!!!
                        for k in range(self.V):
                            if root[k] == h:
                                root[k] = root[g.graph[i][2]]
                        test.append(g.graph[i][0])
                        diction[g.graph[i][1],g.graph[i][2]]= test[-1]
                            
                    else:
                        h = root[g.graph[i][2]] #!!!原本的h放在迴圈裡，這樣他會因為i的不同而更動h的值!!!
                        for k in range(self.V):
                            if root[k] == h:
                                root[k] = root[g.graph[i][1]]
                        test.append(g.graph[i][0])
                        diction[g.graph[i][1],g.graph[i][2]]= test[-1]

                    
            elif root[g.graph[i][1]] == root[g.graph[i][2]]: #兩個root一樣
                if root[g.graph[i][1]] == -1: #都是-1
                    if g.graph[i][1] < g.graph[i][2]:
                        root[g.graph[i][2]] = g.graph[i][1]
                        root[g.graph[i][1]] = g.graph[i][1]
                        test.append(g.graph[i][0])
                        diction[g.graph[i][1],g.graph[i][2]]= test[-1]

                    else: 
                        root[g.graph[i][1]] = g.graph[i][2]
                        root[g.graph[i][2]] = g.graph[i][2]
                        test.append(g.graph[i][0])
                        diction[g.graph[i][1],g.graph[i][2]]= test[-1]
                else: #都不是-1，所以不用連edge
                    continue
                    

            if len(test) == (len(root)-1):   
                return diction

# %%
#最後的刪減版
from collections import defaultdict 

class Graph(): 

    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [] 
        self.graph_matrix = [[0 for column in range(vertices)]  
                    for row in range(vertices)]
    def addEdge(self,u,v,w): 
        self.graph.append([w,u,v]) 
        
    def Dijkstra(self, s): 
        test = [False] * self.V 
        dist = [float('inf')] * self.V
        
        dist[s] = 0
        
        while test != [True] * self.V:
            for i in range(self.V):
                if g.graph[s][i] != 0 and dist[s] + g.graph[s][i] < dist[i]:
                    dist[i] = dist[s] + g.graph[s][i]
                           
            m = float('inf')
            for k in range(self.V):
                if test[k] == False and dist[k] < m :
                    m = dist[k]
                    s = k         
            test[s] = True
            
            diction = {} 
            if test == [True] * self.V:
                for i in range(self.V):
                    diction[str(i)] = dist [i]
                return diction

    def Kruskal(self):
        g.graph.sort()
        root = []
        test = []
        diction={} 

        for i in range(self.V):
            root.append(-1)
        
        for i in range(0,len(g.graph)):
                
            if root[g.graph[i][1]] != root[g.graph[i][2]]:
                if root[g.graph[i][1]] == -1:
                    root[g.graph[i][1]] = root[g.graph[i][2]]
          
                elif root[g.graph[i][2]] == -1:
                    root[g.graph[i][2]] = root[g.graph[i][1]]

                else:
                    if root[g.graph[i][1]] > root[g.graph[i][2]]:
                        h = root[g.graph[i][1]]
                        for k in range(self.V):
                            if root[k] == h:
                                root[k] = root[g.graph[i][2]]
 
                    else:
                        h = root[g.graph[i][2]]
                        for k in range(self.V):
                            if root[k] == h:
                                root[k] = root[g.graph[i][1]]
  
            elif root[g.graph[i][1]] == root[g.graph[i][2]]:
                if root[g.graph[i][1]] == -1:
                    if g.graph[i][1] < g.graph[i][2]:
                        root[g.graph[i][2]] = g.graph[i][1]
                        root[g.graph[i][1]] = g.graph[i][1]

                    else:
                        root[g.graph[i][1]] = g.graph[i][2]
                        root[g.graph[i][2]] = g.graph[i][2]
                        
                else:
                    continue
            a = str(g.graph[i][1])
            b = str(g.graph[i][2])
            c = str(a+'-'+b)
            test.append(g.graph[i][0])
            diction[c]= test[-1]

            if len(test) == (len(root)-1):   
                return diction

# %%
g = Graph(7)
g.addEdge(0, 1, 5)
g.addEdge(0, 5, 3)
g.addEdge(1, 0, 5)
g.addEdge(1, 2, 10)
g.addEdge(1, 4, 1)
g.addEdge(1, 6, 4)
g.addEdge(2, 1, 10)
g.addEdge(2, 3, 5)
g.addEdge(2, 6, 8)
g.addEdge(3, 2, 5)
g.addEdge(3, 4, 7)
g.addEdge(3, 6, 9)
g.addEdge(4, 1, 1)
g.addEdge(4, 3, 7)
g.addEdge(4, 5, 6)
g.addEdge(4, 6, 2)
g.addEdge(5, 0, 3)
g.addEdge(5, 4, 6)
g.addEdge(6, 1, 4)
g.addEdge(6, 2, 8)
g.addEdge(6, 3, 9)
g.addEdge(6, 4, 2)

print("Kruskal",g.Kruskal()) #(1,4,1)(4,6,2)(0,5,3)(0,1,5)(2,3,5)(3,4,7)
# Out:
# Kruskal {'1-4': 1, '4-6': 2, '0-5': 3, '0-1': 5, '2-3': 5, '3-4': 7}

# %%
g = Graph(9)
g.graph=[[0,4,0,0,0,0,0,8,0],
         [4,0,8,0,0,0,0,11,0],
         [0,8,0,7,0,4,0,0,2],
         [0,0,7,0,9,14,0,0,0],
         [0,0,0,9,0,10,0,0,0],
         [0,0,4,14,10,0,2,0,0],
         [0,0,0,0,0,2,0,1,6],
         [8,11,0,0,0,0,1,0,7],
         [0,0,2,0,0,0,6,7,0]
        ];

print("Dijkstra",g.Dijkstra(0))
#(0,0)(1,4)(2,12)(3,19)(4,21)(5,11)(6,9)(7,8)(8,14)

g = Graph(4)
g.addEdge(0,1,10)
g.addEdge(0,2,6)
g.addEdge(0,3,5)
g.addEdge(1,3,15)
g.addEdge(2,3,4)

print("Kruskal",g.Kruskal())
#(2-3:4, 0-3:5, 0-1:10)
# Out:
# Dijkstra {'0': 0, '1': 4, '2': 12, '3': 19, '4': 21, '5': 11, '6': 9, '7': 8, '8': 14}
# Kruskal {'2-3': 4, '0-3': 5, '0-1': 10}

# %%
data={"A":"123","B":"456"}
print(data.keys())
print(data.values())
# Out:
# dict_keys(['A', 'B'])
# dict_values(['123', '456'])

# %% [markdown]
# 流程圖
# =
#
# Dijkstra
# -
# ![](https://i.imgur.com/yuwJk9w.jpg)
#
# Kruskal
# -
# ![](https://i.imgur.com/Kf3sX8t.jpg)

# %% [markdown]
# 參考資料<br>
# https://blog.csdn.net/hellojoy/article/details/81077019 #無限大寫法<br>
# https://www.geeksforgeeks.org/python-program-for-dijkstras-shortest-path-algorithm-greedy-algo-7/<br>
# https://ithelp.ithome.com.tw/m/articles/10209593<br>
# https://blog.csdn.net/ychw365/article/details/8662993 #sort list<br>
# https://www.geeksforgeeks.org/kruskals-minimum-spanning-tree-algorithm-greedy-algo-2/ #addedge<br>
